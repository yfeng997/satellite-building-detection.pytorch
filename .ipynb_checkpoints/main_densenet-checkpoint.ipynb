# %% [markdown]
# # Residential Building Classification
# This is a bare-bone version of the residential vs. non-residential building classification. We use DenseNet in this implementation.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from torchvision import transforms

import numpy as np
import cv2
import matplotlib.pyplot as plt

import params
from densenet_efficient import DenseNetEfficient
from solver import train, test_epoch
from dataset import *

# Load parameters
params = vars(params)
rbc_class_names = params['rbc_class_names']
fmow_class_names = params['fmow_class_names']
fmow_class_names_mini = params['fmow_class_names_mini']
dtype = params['dtype']

torch.set_num_threads(params['num_threads'])

# %% [markdown]
# ## Preprocess FMOW Dataset
# Check if fMoW dataset is available. If so, process the images by cropping based on given bounding boxes. Load in traing, validation and test dataset along with ground truth labels for training and validation set.

# %%
mean = 0.5 #457.38
stdv = 0.25
train_transforms = transforms.Compose([
    Normalize(mean=mean, std=stdv),
    Rescale((224,224)),
    ToTensor(),
])
train_set = FMOWDataset(params, transform=train_transforms)
print("Number of Training/Validation Images: %i" % len(train_set))
x,y = train_set[0]
print(type(x), x.shape, type(y), y.shape)
# Out:
# Number of Training/Validation Images: 30768
# <class 'torch.FloatTensor'> torch.Size([1, 224, 224]) <class 'torch.LongTensor'> torch.Size([1])

# %%
mean = 0.5 #457.38
stdv = 0.25
test_transforms = transforms.Compose([
    Normalize(mean=mean, std=stdv),
    Rescale((224,224)),
    ToTensor(),
])
test_set = FMOWDataset(params, transform=test_transforms, train=False)
print("Number of Testing Images: %i" % len(test_set))
x,y = test_set[0]
print(type(x), x.shape, type(y), y.shape)
# Out:
# Number of Testing Images: 10006
# <class 'torch.FloatTensor'> torch.Size([1, 224, 224]) <class 'torch.LongTensor'> torch.Size([1])

# %%
# data_test = load_test(params, mean_image=None)
# X_test = data_test['X_test']
# y_test = data_test['y_test']
# X_test_tensor = torch.from_numpy(X_test)
# y_test_tensor = torch.from_numpy(y_test)
# test_data = TensorDataset(X_test_tensor, y_test_tensor)
# loader_test = DataLoader(test_data, batch_size=params['batch_size'], sampler=RandomSampler(X_test.shape[0]))
# print(X_test.shape, X_test.dtype)
# print(y_test.shape, y_test.dtype)
# print(y_test)

# %% [markdown]
# ### Visualize a small batch of data
# Plot a small batch of training images to get a sense of data

# %%
# Sample a minibatch and show the images and captions
size = 5
indices = np.random.choice(len(train_set), size, replace=False)

fig = plt.figure()

for i, idx in enumerate(indices):
    image, label = train_set[idx]
    plt.subplot(1, size, i + 1)
    plt.title(params['rbc_class_names'][label[0]])
    plt.axis('off')
    plt.imshow(image[0,:,:])
    plt.show()

# %% [markdown]
# ## Load Model
# Load in DenseNet. Configure training parameters.

# %%
model = DenseNetEfficient(
        growth_rate=32, 
        block_config=(6, 12, 24, 16), 
        compression=0.5,
        num_init_features=64, 
        bn_size=4, 
        drop_rate=0,
        num_classes=20, 
        small_inputs=False)
# Move model to GPU
model = model.cuda()
# print(model)
pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(pytorch_total_params)
# Out:
# /home/feng/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/container.py:13: UserWarning: nn.Container is deprecated. All of it's functionality is now implemented in nn.Module. Subclass that instead.
#   warnings.warn("nn.Container is deprecated. All of it's functionality "

# %%
# Load an existing model trained on 20 categories
model.load_state_dict(torch.load('/home/feng/ext2/feng/workspace/residential_building_challenge/output/model.dat'))

# %%
# Modify the model to predict 2 categories
model.classifier = nn.Sequential(
              nn.Linear(1024, 128),
              nn.ReLU(),
              nn.Linear(128, 2))

# %% [markdown]
# ## Train Model
# Train the model one epoch at a time. Keep the verbose option on to monitor the loss during training.
# Save training and validation accuracy history for visualization.

# %%
train(model, 
      train_set, 
      None, 
      '/home/feng/ext2/feng/workspace/residential_building_challenge/20to2_fmow_output', 
      n_epochs=20, 
      valid_size=1000,
      batch_size=50, 
      lr=0.01, 
      wd=0.0001, 
      momentum=0.9, 
      seed=None)
# Out:
# Epoch: [1/20]	Iter: [1/596]	Time 1.332 (1.332)	Loss 0.6954 (0.6954)	Error 0.5200 (0.5200)
# Epoch: [1/20]	Iter: [2/596]	Time 0.785 (1.058)	Loss 0.7050 (0.7002)	Error 0.6200 (0.5700)
# Epoch: [1/20]	Iter: [3/596]	Time 0.855 (0.991)	Loss 0.6979 (0.6994)	Error 0.5400 (0.5600)
# Epoch: [1/20]	Iter: [4/596]	Time 0.986 (0.990)	Loss 0.6831 (0.6953)	Error 0.5200 (0.5500)
# Epoch: [1/20]	Iter: [5/596]	Time 0.835 (0.959)	Loss 0.6907 (0.6944)	Error 0.5600 (0.5520)
# Epoch: [1/20]	Iter: [6/596]	Time 0.849 (0.940)	Loss 0.6848 (0.6928)	Error 0.4600 (0.5367)
# Epoch: [1/20]	Iter: [7/596]	Time 0.833 (0.925)	Loss 0.6734 (0.6900)	Error 0.2200 (0.4914)
# Epoch: [1/20]	Iter: [8/596]	Time 0.813 (0.911)	Loss 0.6704 (0.6876)	Error 0.2600 (0.4625)
# Epoch: [1/20]	Iter: [9/596]	Time 0.813 (0.900)	Loss 0.6639 (0.6850)	Error 0.2600 (0.4400)
# Epoch: [1/20]	Iter: [10/596]	Time 0.816 (0.892)	Loss 0.6623 (0.6827)	Error 0.3000 (0.4260)
# Epoch: [1/20]	Iter: [11/596]	Time 0.775 (0.881)	Loss 0.6658 (0.6812)	Error 0.4000 (0.4236)
# Epoch: [1/20]	Iter: [12/596]	Time 0.806 (0.875)	Loss 0.6530 (0.6788)	Error 0.3000 (0.4133)
# Epoch: [1/20]	Iter: [13/596]	Time 0.789 (0.868)	Loss 0.6256 (0.6747)	Error 0.0600 (0.3862)
# Epoch: [1/20]	Iter: [14/596]	Time 0.767 (0.861)	Loss 0.6400 (0.6722)	Error 0.3200 (0.3814)
# Epoch: [1/20]	Iter: [15/596]	Time 0.774 (0.855)	Loss 0.6181 (0.6686)	Error 0.1400 (0.3653)
# Epoch: [1/20]	Iter: [16/596]	Time 0.775 (0.850)	Loss 0.6079 (0.6648)	Error 0.1600 (0.3525)
# Epoch: [1/20]	Iter: [17/596]	Time 0.783 (0.846)	Loss 0.6198 (0.6622)	Error 0.2800 (0.3482)
# Epoch: [1/20]	Iter: [18/596]	Time 0.757 (0.841)	Loss 0.6122 (0.6594)	Error 0.1800 (0.3389)
# Epoch: [1/20]	Iter: [19/596]	Time 0.738 (0.836)	Loss 0.5823 (0.6553)	Error 0.1000 (0.3263)
# Epoch: [1/20]	Iter: [20/596]	Time 0.785 (0.833)	Loss 0.5815 (0.6517)	Error 0.1600 (0.3180)
# Epoch: [1/20]	Iter: [21/596]	Time 0.802 (0.832)	Loss 0.5693 (0.6477)	Error 0.1800 (0.3114)
# Epoch: [1/20]	Iter: [22/596]	Time 0.781 (0.830)	Loss 0.5527 (0.6434)	Error 0.1400 (0.3036)
# Epoch: [1/20]	Iter: [23/596]	Time 0.789 (0.828)	Loss 0.5386 (0.6389)	Error 0.1600 (0.2974)
# Epoch: [1/20]	Iter: [24/596]	Time 0.754 (0.825)	Loss 0.5310 (0.6344)	Error 0.1600 (0.2917)
# Epoch: [1/20]	Iter: [25/596]	Time 0.812 (0.824)	Loss 0.5270 (0.6301)	Error 0.2000 (0.2880)
# Epoch: [1/20]	Iter: [26/596]	Time 0.780 (0.822)	Loss 0.4706 (0.6239)	Error 0.1000 (0.2808)
# Epoch: [1/20]	Iter: [27/596]	Time 0.784 (0.821)	Loss 0.5376 (0.6207)	Error 0.2200 (0.2785)
# Epoch: [1/20]	Iter: [28/596]	Time 0.787 (0.820)	Loss 0.4580 (0.6149)	Error 0.1000 (0.2721)
# Epoch: [1/20]	Iter: [29/596]	Time 0.804 (0.819)	Loss 0.4920 (0.6107)	Error 0.2400 (0.2710)
# Epoch: [1/20]	Iter: [30/596]	Time 0.752 (0.817)	Loss 0.5154 (0.6075)	Error 0.2600 (0.2707)
# Epoch: [1/20]	Iter: [31/596]	Time 0.772 (0.816)	Loss 0.4429 (0.6022)	Error 0.1400 (0.2665)
# Epoch: [1/20]	Iter: [32/596]	Time 0.760 (0.814)	Loss 0.4290 (0.5968)	Error 0.1600 (0.2631)
# Epoch: [1/20]	Iter: [33/596]	Time 0.748 (0.812)	Loss 0.4260 (0.5916)	Error 0.1200 (0.2588)
# Epoch: [1/20]	Iter: [34/596]	Time 0.794 (0.811)	Loss 0.4315 (0.5869)	Error 0.1800 (0.2565)
# Epoch: [1/20]	Iter: [35/596]	Time 0.812 (0.811)	Loss 0.4137 (0.5820)	Error 0.1400 (0.2531)
# Epoch: [1/20]	Iter: [36/596]	Time 0.760 (0.810)	Loss 0.3444 (0.5754)	Error 0.0800 (0.2483)
# Epoch: [1/20]	Iter: [37/596]	Time 0.901 (0.812)	Loss 0.4391 (0.5717)	Error 0.1800 (0.2465)
# Epoch: [1/20]	Iter: [38/596]	Time 0.756 (0.811)	Loss 0.3672 (0.5663)	Error 0.1400 (0.2437)
# Epoch: [1/20]	Iter: [39/596]	Time 0.719 (0.809)	Loss 0.3918 (0.5618)	Error 0.1200 (0.2405)
# Epoch: [1/20]	Iter: [40/596]	Time 0.734 (0.807)	Loss 0.3418 (0.5563)	Error 0.0800 (0.2365)
# Epoch: [1/20]	Iter: [41/596]	Time 0.739 (0.805)	Loss 0.3360 (0.5509)	Error 0.1200 (0.2337)
# Epoch: [1/20]	Iter: [42/596]	Time 0.792 (0.805)	Loss 0.4666 (0.5489)	Error 0.2600 (0.2343)
# Epoch: [1/20]	Iter: [43/596]	Time 0.801 (0.805)	Loss 0.3894 (0.5452)	Error 0.1600 (0.2326)
# Epoch: [1/20]	Iter: [44/596]	Time 0.749 (0.803)	Loss 0.3635 (0.5411)	Error 0.2200 (0.2323)
# Epoch: [1/20]	Iter: [45/596]	Time 0.781 (0.803)	Loss 0.3034 (0.5358)	Error 0.1400 (0.2302)
# Epoch: [1/20]	Iter: [46/596]	Time 0.787 (0.803)	Loss 0.2379 (0.5293)	Error 0.1400 (0.2283)
# Epoch: [1/20]	Iter: [47/596]	Time 0.742 (0.801)	Loss 0.3632 (0.5258)	Error 0.1200 (0.2260)
# Epoch: [1/20]	Iter: [48/596]	Time 0.738 (0.800)	Loss 0.2881 (0.5209)	Error 0.1000 (0.2233)
# Epoch: [1/20]	Iter: [49/596]	Time 0.720 (0.798)	Loss 0.3058 (0.5165)	Error 0.1400 (0.2216)
# Epoch: [1/20]	Iter: [50/596]	Time 0.745 (0.797)	Loss 0.3342 (0.5128)	Error 0.1400 (0.2200)
# Epoch: [1/20]	Iter: [51/596]	Time 0.812 (0.798)	Loss 0.5081 (0.5127)	Error 0.2800 (0.2212)
# Epoch: [1/20]	Iter: [52/596]	Time 0.804 (0.798)	Loss 0.4054 (0.5107)	Error 0.1400 (0.2196)
# Epoch: [1/20]	Iter: [53/596]	Time 0.868 (0.799)	Loss 0.4175 (0.5089)	Error 0.2000 (0.2192)
# Epoch: [1/20]	Iter: [54/596]	Time 0.931 (0.801)	Loss 0.3276 (0.5055)	Error 0.1600 (0.2181)
# Epoch: [1/20]	Iter: [55/596]	Time 0.806 (0.802)	Loss 0.2586 (0.5011)	Error 0.1400 (0.2167)
# Epoch: [1/20]	Iter: [56/596]	Time 0.861 (0.803)	Loss 0.3309 (0.4980)	Error 0.1200 (0.2150)
# Epoch: [1/20]	Iter: [57/596]	Time 0.805 (0.803)	Loss 0.2234 (0.4932)	Error 0.1000 (0.2130)
# Epoch: [1/20]	Iter: [58/596]	Time 0.802 (0.803)	Loss 0.2794 (0.4895)	Error 0.1000 (0.2110)
# Epoch: [1/20]	Iter: [59/596]	Time 0.820 (0.803)	Loss 0.3603 (0.4873)	Error 0.1200 (0.2095)
# Epoch: [1/20]	Iter: [60/596]	Time 0.787 (0.803)	Loss 0.3097 (0.4844)	Error 0.1600 (0.2087)
# Epoch: [1/20]	Iter: [61/596]	Time 0.790 (0.802)	Loss 0.4100 (0.4831)	Error 0.1800 (0.2082)
# Epoch: [1/20]	Iter: [62/596]	Time 0.840 (0.803)	Loss 0.2746 (0.4798)	Error 0.1000 (0.2065)
# Epoch: [1/20]	Iter: [63/596]	Time 0.954 (0.805)	Loss 0.3931 (0.4784)	Error 0.1400 (0.2054)
# Epoch: [1/20]	Iter: [64/596]	Time 0.799 (0.805)	Loss 0.4113 (0.4774)	Error 0.1600 (0.2047)
# Epoch: [1/20]	Iter: [65/596]	Time 0.859 (0.806)	Loss 0.3398 (0.4752)	Error 0.1200 (0.2034)
# Epoch: [1/20]	Iter: [66/596]	Time 0.813 (0.806)	Loss 0.3186 (0.4729)	Error 0.0800 (0.2015)
# Epoch: [1/20]	Iter: [67/596]	Time 0.780 (0.806)	Loss 0.4222 (0.4721)	Error 0.1400 (0.2006)
# Epoch: [1/20]	Iter: [68/596]	Time 0.794 (0.806)	Loss 0.2052 (0.4682)	Error 0.0600 (0.1985)
# Epoch: [1/20]	Iter: [69/596]	Time 0.858 (0.806)	Loss 0.2716 (0.4653)	Error 0.0800 (0.1968)
# Epoch: [1/20]	Iter: [70/596]	Time 0.832 (0.807)	Loss 0.3119 (0.4631)	Error 0.1000 (0.1954)
# Epoch: [1/20]	Iter: [71/596]	Time 0.809 (0.807)	Loss 0.2240 (0.4598)	Error 0.0600 (0.1935)
# Epoch: [1/20]	Iter: [72/596]	Time 0.793 (0.807)	Loss 0.2373 (0.4567)	Error 0.1200 (0.1925)
# Epoch: [1/20]	Iter: [73/596]	Time 0.771 (0.806)	Loss 0.2897 (0.4544)	Error 0.1400 (0.1918)
# Epoch: [1/20]	Iter: [74/596]	Time 0.804 (0.806)	Loss 0.3553 (0.4531)	Error 0.1400 (0.1911)
# Epoch: [1/20]	Iter: [75/596]	Time 0.859 (0.807)	Loss 0.2789 (0.4507)	Error 0.1200 (0.1901)
# Epoch: [1/20]	Iter: [76/596]	Time 0.764 (0.806)	Loss 0.3052 (0.4488)	Error 0.1400 (0.1895)
# Epoch: [1/20]	Iter: [77/596]	Time 0.945 (0.808)	Loss 0.3027 (0.4469)	Error 0.1400 (0.1888)
# Epoch: [1/20]	Iter: [78/596]	Time 0.797 (0.808)	Loss 0.2601 (0.4445)	Error 0.1400 (0.1882)
# Epoch: [1/20]	Iter: [79/596]	Time 0.858 (0.809)	Loss 0.3186 (0.4429)	Error 0.1600 (0.1878)
# Epoch: [1/20]	Iter: [80/596]	Time 0.794 (0.808)	Loss 0.3168 (0.4414)	Error 0.1600 (0.1875)
# Epoch: [1/20]	Iter: [81/596]	Time 0.815 (0.808)	Loss 0.4791 (0.4418)	Error 0.2000 (0.1877)
# Epoch: [1/20]	Iter: [82/596]	Time 0.799 (0.808)	Loss 0.3533 (0.4407)	Error 0.1400 (0.1871)
# Epoch: [1/20]	Iter: [83/596]	Time 0.876 (0.809)	Loss 0.2478 (0.4384)	Error 0.1400 (0.1865)
# Epoch: [1/20]	Iter: [84/596]	Time 0.864 (0.810)	Loss 0.2533 (0.4362)	Error 0.0800 (0.1852)
# Epoch: [1/20]	Iter: [85/596]	Time 0.831 (0.810)	Loss 0.1558 (0.4329)	Error 0.0400 (0.1835)
# Epoch: [1/20]	Iter: [86/596]	Time 0.853 (0.811)	Loss 0.4450 (0.4331)	Error 0.2000 (0.1837)
# Epoch: [1/20]	Iter: [87/596]	Time 0.806 (0.810)	Loss 0.3119 (0.4317)	Error 0.1400 (0.1832)
# Epoch: [1/20]	Iter: [88/596]	Time 1.222 (0.815)	Loss 0.4112 (0.4314)	Error 0.1600 (0.1830)
# Epoch: [1/20]	Iter: [89/596]	Time 0.812 (0.815)	Loss 0.1848 (0.4287)	Error 0.0800 (0.1818)
# Epoch: [1/20]	Iter: [90/596]	Time 0.907 (0.816)	Loss 0.3163 (0.4274)	Error 0.1200 (0.1811)
# Epoch: [1/20]	Iter: [91/596]	Time 0.789 (0.816)	Loss 0.3577 (0.4266)	Error 0.1800 (0.1811)
# Epoch: [1/20]	Iter: [92/596]	Time 0.817 (0.816)	Loss 0.2759 (0.4250)	Error 0.0800 (0.1800)
# Epoch: [1/20]	Iter: [93/596]	Time 0.935 (0.817)	Loss 0.4666 (0.4255)	Error 0.1800 (0.1800)
# Epoch: [1/20]	Iter: [94/596]	Time 0.807 (0.817)	Loss 0.2198 (0.4233)	Error 0.0400 (0.1785)
# Epoch: [1/20]	Iter: [95/596]	Time 0.816 (0.817)	Loss 0.4438 (0.4235)	Error 0.2000 (0.1787)
# Epoch: [1/20]	Iter: [96/596]	Time 0.831 (0.817)	Loss 0.3862 (0.4231)	Error 0.1800 (0.1787)
# Epoch: [1/20]	Iter: [97/596]	Time 0.789 (0.817)	Loss 0.3019 (0.4218)	Error 0.1000 (0.1779)
# Epoch: [1/20]	Iter: [98/596]	Time 0.846 (0.817)	Loss 0.4144 (0.4218)	Error 0.1200 (0.1773)
# Epoch: [1/20]	Iter: [99/596]	Time 0.836 (0.817)	Loss 0.2267 (0.4198)	Error 0.0800 (0.1764)
# Epoch: [1/20]	Iter: [100/596]	Time 0.904 (0.818)	Loss 0.3680 (0.4193)	Error 0.1800 (0.1764)
# Epoch: [1/20]	Iter: [101/596]	Time 0.821 (0.818)	Loss 0.2651 (0.4178)	Error 0.1000 (0.1756)
# Epoch: [1/20]	Iter: [102/596]	Time 0.795 (0.818)	Loss 0.4481 (0.4181)	Error 0.2800 (0.1767)
# Epoch: [1/20]	Iter: [103/596]	Time 0.834 (0.818)	Loss 0.3751 (0.4176)	Error 0.1800 (0.1767)
# Epoch: [1/20]	Iter: [104/596]	Time 0.799 (0.818)	Loss 0.4078 (0.4175)	Error 0.2000 (0.1769)
# Epoch: [1/20]	Iter: [105/596]	Time 0.784 (0.818)	Loss 0.2983 (0.4164)	Error 0.1600 (0.1768)
# Epoch: [1/20]	Iter: [106/596]	Time 0.800 (0.818)	Loss 0.3697 (0.4160)	Error 0.1600 (0.1766)
# Epoch: [1/20]	Iter: [107/596]	Time 0.790 (0.817)	Loss 0.2933 (0.4148)	Error 0.1200 (0.1761)
# Epoch: [1/20]	Iter: [108/596]	Time 0.827 (0.817)	Loss 0.3375 (0.4141)	Error 0.1400 (0.1757)
# Epoch: [1/20]	Iter: [109/596]	Time 0.820 (0.817)	Loss 0.4390 (0.4143)	Error 0.1600 (0.1756)
# Epoch: [1/20]	Iter: [110/596]	Time 0.783 (0.817)	Loss 0.2607 (0.4129)	Error 0.1400 (0.1753)
# Epoch: [1/20]	Iter: [111/596]	Time 0.791 (0.817)	Loss 0.1604 (0.4107)	Error 0.0400 (0.1741)
# Epoch: [1/20]	Iter: [112/596]	Time 0.856 (0.817)	Loss 0.3778 (0.4104)	Error 0.1400 (0.1737)
# Epoch: [1/20]	Iter: [113/596]	Time 0.772 (0.817)	Loss 0.4072 (0.4103)	Error 0.1800 (0.1738)
# Epoch: [1/20]	Iter: [114/596]	Time 0.809 (0.817)	Loss 0.4435 (0.4106)	Error 0.1800 (0.1739)
# Epoch: [1/20]	Iter: [115/596]	Time 0.803 (0.817)	Loss 0.3525 (0.4101)	Error 0.1600 (0.1737)
# Epoch: [1/20]	Iter: [116/596]	Time 0.804 (0.817)	Loss 0.2824 (0.4090)	Error 0.1200 (0.1733)
# Epoch: [1/20]	Iter: [117/596]	Time 0.845 (0.817)	Loss 0.2419 (0.4076)	Error 0.1000 (0.1726)
# Epoch: [1/20]	Iter: [118/596]	Time 0.835 (0.817)	Loss 0.2841 (0.4065)	Error 0.0800 (0.1719)
# Epoch: [1/20]	Iter: [119/596]	Time 0.784 (0.817)	Loss 0.3144 (0.4058)	Error 0.1400 (0.1716)
# Epoch: [1/20]	Iter: [120/596]	Time 0.843 (0.817)	Loss 0.2529 (0.4045)	Error 0.0600 (0.1707)
# Epoch: [1/20]	Iter: [121/596]	Time 0.836 (0.817)	Loss 0.3590 (0.4041)	Error 0.1800 (0.1707)
# Epoch: [1/20]	Iter: [122/596]	Time 0.797 (0.817)	Loss 0.2143 (0.4026)	Error 0.1000 (0.1702)
# Epoch: [1/20]	Iter: [123/596]	Time 0.855 (0.817)	Loss 0.3112 (0.4018)	Error 0.1600 (0.1701)
# Epoch: [1/20]	Iter: [124/596]	Time 0.849 (0.817)	Loss 0.2902 (0.4009)	Error 0.1400 (0.1698)
# Epoch: [1/20]	Iter: [125/596]	Time 0.811 (0.817)	Loss 0.2687 (0.3999)	Error 0.1200 (0.1694)
# Epoch: [1/20]	Iter: [126/596]	Time 0.779 (0.817)	Loss 0.2056 (0.3983)	Error 0.0600 (0.1686)
# Epoch: [1/20]	Iter: [127/596]	Time 0.795 (0.817)	Loss 0.3657 (0.3981)	Error 0.1400 (0.1683)
# Epoch: [1/20]	Iter: [128/596]	Time 0.809 (0.817)	Loss 0.3509 (0.3977)	Error 0.1800 (0.1684)
# Epoch: [1/20]	Iter: [129/596]	Time 0.920 (0.818)	Loss 0.2627 (0.3967)	Error 0.1200 (0.1681)
# Epoch: [1/20]	Iter: [130/596]	Time 0.825 (0.818)	Loss 0.2702 (0.3957)	Error 0.1200 (0.1677)
# Epoch: [1/20]	Iter: [131/596]	Time 0.850 (0.818)	Loss 0.3924 (0.3957)	Error 0.1400 (0.1675)
# Epoch: [1/20]	Iter: [132/596]	Time 0.835 (0.818)	Loss 0.2233 (0.3943)	Error 0.1000 (0.1670)
# Epoch: [1/20]	Iter: [133/596]	Time 0.819 (0.818)	Loss 0.2414 (0.3932)	Error 0.0600 (0.1662)
# Epoch: [1/20]	Iter: [134/596]	Time 0.820 (0.818)	Loss 0.3204 (0.3927)	Error 0.1200 (0.1658)
# Epoch: [1/20]	Iter: [135/596]	Time 0.802 (0.818)	Loss 0.2436 (0.3916)	Error 0.0800 (0.1652)
# Epoch: [1/20]	Iter: [136/596]	Time 0.849 (0.818)	Loss 0.2450 (0.3905)	Error 0.0600 (0.1644)
# Epoch: [1/20]	Iter: [137/596]	Time 0.806 (0.818)	Loss 0.4210 (0.3907)	Error 0.2400 (0.1650)
# Epoch: [1/20]	Iter: [138/596]	Time 0.876 (0.819)	Loss 0.2881 (0.3900)	Error 0.1000 (0.1645)
# Epoch: [1/20]	Iter: [139/596]	Time 0.793 (0.818)	Loss 0.3821 (0.3899)	Error 0.1400 (0.1643)
# Epoch: [1/20]	Iter: [140/596]	Time 0.856 (0.819)	Loss 0.3386 (0.3895)	Error 0.2000 (0.1646)
# Epoch: [1/20]	Iter: [141/596]	Time 0.879 (0.819)	Loss 0.1791 (0.3880)	Error 0.0200 (0.1635)
# Epoch: [1/20]	Iter: [142/596]	Time 0.831 (0.819)	Loss 0.4422 (0.3884)	Error 0.2400 (0.1641)
# Epoch: [1/20]	Iter: [143/596]	Time 0.828 (0.819)	Loss 0.2569 (0.3875)	Error 0.1200 (0.1638)
# Epoch: [1/20]	Iter: [144/596]	Time 0.814 (0.819)	Loss 0.4460 (0.3879)	Error 0.2600 (0.1644)
# Epoch: [1/20]	Iter: [145/596]	Time 0.802 (0.819)	Loss 0.3212 (0.3874)	Error 0.1200 (0.1641)
# Epoch: [1/20]	Iter: [146/596]	Time 0.802 (0.819)	Loss 0.4178 (0.3877)	Error 0.2200 (0.1645)
# Epoch: [1/20]	Iter: [147/596]	Time 0.866 (0.819)	Loss 0.2485 (0.3867)	Error 0.1200 (0.1642)
# Epoch: [1/20]	Iter: [148/596]	Time 0.854 (0.819)	Loss 0.2648 (0.3859)	Error 0.1000 (0.1638)
# Epoch: [1/20]	Iter: [149/596]	Time 0.841 (0.820)	Loss 0.2826 (0.3852)	Error 0.1200 (0.1635)
# Epoch: [1/20]	Iter: [150/596]	Time 0.845 (0.820)	Loss 0.2929 (0.3846)	Error 0.1400 (0.1633)
# Epoch: [1/20]	Iter: [151/596]	Time 0.859 (0.820)	Loss 0.2927 (0.3840)	Error 0.1200 (0.1630)
# Epoch: [1/20]	Iter: [152/596]	Time 0.786 (0.820)	Loss 0.2484 (0.3831)	Error 0.1000 (0.1626)
# Epoch: [1/20]	Iter: [153/596]	Time 0.812 (0.820)	Loss 0.3834 (0.3831)	Error 0.2600 (0.1633)
# Epoch: [1/20]	Iter: [154/596]	Time 0.809 (0.820)	Loss 0.2898 (0.3825)	Error 0.1400 (0.1631)
# Epoch: [1/20]	Iter: [155/596]	Time 0.830 (0.820)	Loss 0.2352 (0.3815)	Error 0.1000 (0.1627)
# Epoch: [1/20]	Iter: [156/596]	Time 0.840 (0.820)	Loss 0.3968 (0.3816)	Error 0.1600 (0.1627)
# Epoch: [1/20]	Iter: [157/596]	Time 0.803 (0.820)	Loss 0.2634 (0.3809)	Error 0.1200 (0.1624)
# Epoch: [1/20]	Iter: [158/596]	Time 0.939 (0.821)	Loss 0.2713 (0.3802)	Error 0.1200 (0.1622)
# Epoch: [1/20]	Iter: [159/596]	Time 0.773 (0.820)	Loss 0.2331 (0.3792)	Error 0.1200 (0.1619)
# Epoch: [1/20]	Iter: [160/596]	Time 0.800 (0.820)	Loss 0.2835 (0.3787)	Error 0.1200 (0.1616)
# Epoch: [1/20]	Iter: [161/596]	Time 0.819 (0.820)	Loss 0.1450 (0.3772)	Error 0.0000 (0.1606)
# Epoch: [1/20]	Iter: [162/596]	Time 0.835 (0.820)	Loss 0.3378 (0.3770)	Error 0.1000 (0.1602)
# Epoch: [1/20]	Iter: [163/596]	Time 0.821 (0.820)	Loss 0.3322 (0.3767)	Error 0.1400 (0.1601)
# Epoch: [1/20]	Iter: [164/596]	Time 0.825 (0.820)	Loss 0.2747 (0.3761)	Error 0.1000 (0.1598)
# Epoch: [1/20]	Iter: [165/596]	Time 0.877 (0.821)	Loss 0.3427 (0.3759)	Error 0.1600 (0.1598)
# Epoch: [1/20]	Iter: [166/596]	Time 0.802 (0.820)	Loss 0.2379 (0.3750)	Error 0.0800 (0.1593)
# Epoch: [1/20]	Iter: [167/596]	Time 0.810 (0.820)	Loss 0.3257 (0.3747)	Error 0.1600 (0.1593)
# Epoch: [1/20]	Iter: [168/596]	Time 0.842 (0.821)	Loss 0.2624 (0.3741)	Error 0.1000 (0.1589)
# Epoch: [1/20]	Iter: [169/596]	Time 0.875 (0.821)	Loss 0.2664 (0.3734)	Error 0.1200 (0.1587)
# Epoch: [1/20]	Iter: [170/596]	Time 0.804 (0.821)	Loss 0.3087 (0.3730)	Error 0.1400 (0.1586)
# Epoch: [1/20]	Iter: [171/596]	Time 1.049 (0.822)	Loss 0.2380 (0.3723)	Error 0.0800 (0.1581)
# Epoch: [1/20]	Iter: [172/596]	Time 0.808 (0.822)	Loss 0.2700 (0.3717)	Error 0.1200 (0.1579)
# Epoch: [1/20]	Iter: [173/596]	Time 0.833 (0.822)	Loss 0.2445 (0.3709)	Error 0.1200 (0.1577)
# Epoch: [1/20]	Iter: [174/596]	Time 0.837 (0.822)	Loss 0.2162 (0.3700)	Error 0.1000 (0.1574)
# Epoch: [1/20]	Iter: [175/596]	Time 0.837 (0.822)	Loss 0.1928 (0.3690)	Error 0.0800 (0.1569)
# Epoch: [1/20]	Iter: [176/596]	Time 0.801 (0.822)	Loss 0.2941 (0.3686)	Error 0.1400 (0.1568)
# Epoch: [1/20]	Iter: [177/596]	Time 0.809 (0.822)	Loss 0.2396 (0.3679)	Error 0.1200 (0.1566)
# Epoch: [1/20]	Iter: [178/596]	Time 0.785 (0.822)	Loss 0.2367 (0.3671)	Error 0.1000 (0.1563)
# Epoch: [1/20]	Iter: [179/596]	Time 0.808 (0.822)	Loss 0.3861 (0.3672)	Error 0.1000 (0.1560)
# Epoch: [1/20]	Iter: [180/596]	Time 0.833 (0.822)	Loss 0.6195 (0.3686)	Error 0.2400 (0.1564)
# Epoch: [1/20]	Iter: [181/596]	Time 0.827 (0.822)	Loss 0.2535 (0.3680)	Error 0.1600 (0.1565)
# Epoch: [1/20]	Iter: [182/596]	Time 0.814 (0.822)	Loss 0.4394 (0.3684)	Error 0.2000 (0.1567)
# Epoch: [1/20]	Iter: [183/596]	Time 0.799 (0.822)	Loss 0.2493 (0.3677)	Error 0.1200 (0.1565)
# Epoch: [1/20]	Iter: [184/596]	Time 0.856 (0.822)	Loss 0.4661 (0.3683)	Error 0.1600 (0.1565)
# Epoch: [1/20]	Iter: [185/596]	Time 0.791 (0.822)	Loss 0.1671 (0.3672)	Error 0.0800 (0.1561)
# Epoch: [1/20]	Iter: [186/596]	Time 0.834 (0.822)	Loss 0.2843 (0.3667)	Error 0.1400 (0.1560)
# Epoch: [1/20]	Iter: [187/596]	Time 0.838 (0.822)	Loss 0.4351 (0.3671)	Error 0.2000 (0.1563)
# Epoch: [1/20]	Iter: [188/596]	Time 0.901 (0.822)	Loss 0.1581 (0.3660)	Error 0.0400 (0.1556)
# Epoch: [1/20]	Iter: [189/596]	Time 0.834 (0.822)	Loss 0.2530 (0.3654)	Error 0.0800 (0.1552)
# Epoch: [1/20]	Iter: [190/596]	Time 0.837 (0.822)	Loss 0.3806 (0.3655)	Error 0.1400 (0.1552)
# Epoch: [1/20]	Iter: [191/596]	Time 0.820 (0.822)	Loss 0.1588 (0.3644)	Error 0.0400 (0.1546)
# Epoch: [1/20]	Iter: [192/596]	Time 0.834 (0.822)	Loss 0.3224 (0.3642)	Error 0.1200 (0.1544)
# Epoch: [1/20]	Iter: [193/596]	Time 0.812 (0.822)	Loss 0.2409 (0.3635)	Error 0.1000 (0.1541)
# Epoch: [1/20]	Iter: [194/596]	Time 0.827 (0.822)	Loss 0.4226 (0.3638)	Error 0.1400 (0.1540)
# Epoch: [1/20]	Iter: [195/596]	Time 0.811 (0.822)	Loss 0.2154 (0.3631)	Error 0.0600 (0.1535)
# Epoch: [1/20]	Iter: [196/596]	Time 0.802 (0.822)	Loss 0.4341 (0.3634)	Error 0.2000 (0.1538)
# Epoch: [1/20]	Iter: [197/596]	Time 0.786 (0.822)	Loss 0.1688 (0.3625)	Error 0.0400 (0.1532)
# Epoch: [1/20]	Iter: [198/596]	Time 0.810 (0.822)	Loss 0.2732 (0.3620)	Error 0.1600 (0.1532)
# Epoch: [1/20]	Iter: [199/596]	Time 0.840 (0.822)	Loss 0.3432 (0.3619)	Error 0.1200 (0.1531)
# Epoch: [1/20]	Iter: [200/596]	Time 0.838 (0.822)	Loss 0.4047 (0.3621)	Error 0.1600 (0.1531)
# Epoch: [1/20]	Iter: [201/596]	Time 0.808 (0.822)	Loss 0.4523 (0.3626)	Error 0.2200 (0.1534)
# Epoch: [1/20]	Iter: [202/596]	Time 0.871 (0.822)	Loss 0.1798 (0.3617)	Error 0.0600 (0.1530)
# Epoch: [1/20]	Iter: [203/596]	Time 0.853 (0.823)	Loss 0.2796 (0.3613)	Error 0.0800 (0.1526)
# Epoch: [1/20]	Iter: [204/596]	Time 0.796 (0.822)	Loss 0.1940 (0.3604)	Error 0.0800 (0.1523)
# Epoch: [1/20]	Iter: [205/596]	Time 0.845 (0.822)	Loss 0.2936 (0.3601)	Error 0.1400 (0.1522)
# Epoch: [1/20]	Iter: [206/596]	Time 0.818 (0.822)	Loss 0.2319 (0.3595)	Error 0.1000 (0.1519)
# Epoch: [1/20]	Iter: [207/596]	Time 0.814 (0.822)	Loss 0.3983 (0.3597)	Error 0.2000 (0.1522)
# Epoch: [1/20]	Iter: [208/596]	Time 0.875 (0.823)	Loss 0.2166 (0.3590)	Error 0.1000 (0.1519)
# Epoch: [1/20]	Iter: [209/596]	Time 0.800 (0.823)	Loss 0.3132 (0.3588)	Error 0.1400 (0.1519)
# Epoch: [1/20]	Iter: [210/596]	Time 0.798 (0.822)	Loss 0.3955 (0.3590)	Error 0.1600 (0.1519)
# Epoch: [1/20]	Iter: [211/596]	Time 0.816 (0.822)	Loss 0.3407 (0.3589)	Error 0.1200 (0.1518)
# Epoch: [1/20]	Iter: [212/596]	Time 0.805 (0.822)	Loss 0.2597 (0.3584)	Error 0.1400 (0.1517)
# Epoch: [1/20]	Iter: [213/596]	Time 0.807 (0.822)	Loss 0.1963 (0.3576)	Error 0.0800 (0.1514)
# Epoch: [1/20]	Iter: [214/596]	Time 0.793 (0.822)	Loss 0.2899 (0.3573)	Error 0.1600 (0.1514)
# Epoch: [1/20]	Iter: [215/596]	Time 0.799 (0.822)	Loss 0.3959 (0.3575)	Error 0.2000 (0.1516)
# Epoch: [1/20]	Iter: [216/596]	Time 0.810 (0.822)	Loss 0.1762 (0.3567)	Error 0.0600 (0.1512)
# Epoch: [1/20]	Iter: [217/596]	Time 0.787 (0.822)	Loss 0.2562 (0.3562)	Error 0.1600 (0.1512)
# Epoch: [1/20]	Iter: [218/596]	Time 0.820 (0.822)	Loss 0.1285 (0.3552)	Error 0.0600 (0.1508)
# Epoch: [1/20]	Iter: [219/596]	Time 0.837 (0.822)	Loss 0.4128 (0.3554)	Error 0.1400 (0.1508)
# Epoch: [1/20]	Iter: [220/596]	Time 0.826 (0.822)	Loss 0.3123 (0.3552)	Error 0.1400 (0.1507)
# Epoch: [1/20]	Iter: [221/596]	Time 0.808 (0.822)	Loss 0.2450 (0.3547)	Error 0.1200 (0.1506)
# Epoch: [1/20]	Iter: [222/596]	Time 0.775 (0.822)	Loss 0.2669 (0.3543)	Error 0.0800 (0.1503)
# Epoch: [1/20]	Iter: [223/596]	Time 0.844 (0.822)	Loss 0.3324 (0.3542)	Error 0.1400 (0.1502)
# Epoch: [1/20]	Iter: [224/596]	Time 0.831 (0.822)	Loss 0.3238 (0.3541)	Error 0.1800 (0.1504)
# Epoch: [1/20]	Iter: [225/596]	Time 0.861 (0.822)	Loss 0.1279 (0.3531)	Error 0.0400 (0.1499)
# Epoch: [1/20]	Iter: [226/596]	Time 0.787 (0.822)	Loss 0.4779 (0.3536)	Error 0.2200 (0.1502)
# Epoch: [1/20]	Iter: [227/596]	Time 0.781 (0.822)	Loss 0.2509 (0.3532)	Error 0.1000 (0.1500)
# Epoch: [1/20]	Iter: [228/596]	Time 0.845 (0.822)	Loss 0.2651 (0.3528)	Error 0.0800 (0.1496)
# Epoch: [1/20]	Iter: [229/596]	Time 0.805 (0.822)	Loss 0.4066 (0.3530)	Error 0.1800 (0.1498)
# Epoch: [1/20]	Iter: [230/596]	Time 0.792 (0.822)	Loss 0.3420 (0.3530)	Error 0.1600 (0.1498)
# Epoch: [1/20]	Iter: [231/596]	Time 0.840 (0.822)	Loss 0.2152 (0.3524)	Error 0.0800 (0.1495)
# Epoch: [1/20]	Iter: [232/596]	Time 0.814 (0.822)	Loss 0.3152 (0.3522)	Error 0.1200 (0.1494)
# Epoch: [1/20]	Iter: [233/596]	Time 0.839 (0.822)	Loss 0.4035 (0.3525)	Error 0.1600 (0.1494)
# Epoch: [1/20]	Iter: [234/596]	Time 0.783 (0.821)	Loss 0.3139 (0.3523)	Error 0.1400 (0.1494)
# Epoch: [1/20]	Iter: [235/596]	Time 0.773 (0.821)	Loss 0.3436 (0.3523)	Error 0.1000 (0.1492)
# Epoch: [1/20]	Iter: [236/596]	Time 0.789 (0.821)	Loss 0.2670 (0.3519)	Error 0.1000 (0.1490)
# Epoch: [1/20]	Iter: [237/596]	Time 0.818 (0.821)	Loss 0.2983 (0.3517)	Error 0.1600 (0.1490)
# Epoch: [1/20]	Iter: [238/596]	Time 0.832 (0.821)	Loss 0.2959 (0.3514)	Error 0.1200 (0.1489)
# Epoch: [1/20]	Iter: [239/596]	Time 0.809 (0.821)	Loss 0.2802 (0.3511)	Error 0.1200 (0.1488)
# Epoch: [1/20]	Iter: [240/596]	Time 0.824 (0.821)	Loss 0.1443 (0.3503)	Error 0.0200 (0.1482)
# Epoch: [1/20]	Iter: [241/596]	Time 0.875 (0.821)	Loss 0.3741 (0.3504)	Error 0.1400 (0.1482)
# Epoch: [1/20]	Iter: [242/596]	Time 0.873 (0.822)	Loss 0.2271 (0.3499)	Error 0.1000 (0.1480)
# Epoch: [1/20]	Iter: [243/596]	Time 0.801 (0.821)	Loss 0.1537 (0.3491)	Error 0.0400 (0.1476)
# Epoch: [1/20]	Iter: [244/596]	Time 0.884 (0.822)	Loss 0.2033 (0.3485)	Error 0.0800 (0.1473)
# Epoch: [1/20]	Iter: [245/596]	Time 0.813 (0.822)	Loss 0.3024 (0.3483)	Error 0.1400 (0.1473)
# Epoch: [1/20]	Iter: [246/596]	Time 0.822 (0.822)	Loss 0.2280 (0.3478)	Error 0.1200 (0.1472)
# Epoch: [1/20]	Iter: [247/596]	Time 0.841 (0.822)	Loss 0.2491 (0.3474)	Error 0.1000 (0.1470)
# Epoch: [1/20]	Iter: [248/596]	Time 0.849 (0.822)	Loss 0.1796 (0.3467)	Error 0.0800 (0.1467)
# Epoch: [1/20]	Iter: [249/596]	Time 0.832 (0.822)	Loss 0.3283 (0.3466)	Error 0.1600 (0.1467)
# Epoch: [1/20]	Iter: [250/596]	Time 0.832 (0.822)	Loss 0.3085 (0.3465)	Error 0.0800 (0.1465)
# Epoch: [1/20]	Iter: [251/596]	Time 0.846 (0.822)	Loss 0.2686 (0.3462)	Error 0.1000 (0.1463)
# Epoch: [1/20]	Iter: [252/596]	Time 0.823 (0.822)	Loss 0.2498 (0.3458)	Error 0.1000 (0.1461)
# Epoch: [1/20]	Iter: [253/596]	Time 0.787 (0.822)	Loss 0.4008 (0.3460)	Error 0.1600 (0.1462)
# Epoch: [1/20]	Iter: [254/596]	Time 0.926 (0.822)	Loss 0.2932 (0.3458)	Error 0.1400 (0.1461)
# Epoch: [1/20]	Iter: [255/596]	Time 0.820 (0.822)	Loss 0.2425 (0.3454)	Error 0.1400 (0.1461)
# Epoch: [1/20]	Iter: [256/596]	Time 0.812 (0.822)	Loss 0.3277 (0.3453)	Error 0.1200 (0.1460)
# Epoch: [1/20]	Iter: [257/596]	Time 0.905 (0.823)	Loss 0.3789 (0.3454)	Error 0.1600 (0.1461)
# Epoch: [1/20]	Iter: [258/596]	Time 0.816 (0.823)	Loss 0.2201 (0.3450)	Error 0.0800 (0.1458)
# Epoch: [1/20]	Iter: [259/596]	Time 0.827 (0.823)	Loss 0.1988 (0.3444)	Error 0.0800 (0.1456)
# Epoch: [1/20]	Iter: [260/596]	Time 0.761 (0.822)	Loss 0.2828 (0.3442)	Error 0.1400 (0.1455)
# Epoch: [1/20]	Iter: [261/596]	Time 0.802 (0.822)	Loss 0.2096 (0.3436)	Error 0.0600 (0.1452)
# Epoch: [1/20]	Iter: [262/596]	Time 0.847 (0.822)	Loss 0.3531 (0.3437)	Error 0.1200 (0.1451)
# Epoch: [1/20]	Iter: [263/596]	Time 0.789 (0.822)	Loss 0.2469 (0.3433)	Error 0.1200 (0.1450)
# Epoch: [1/20]	Iter: [264/596]	Time 0.805 (0.822)	Loss 0.2115 (0.3428)	Error 0.0800 (0.1448)
# Epoch: [1/20]	Iter: [265/596]	Time 0.984 (0.823)	Loss 0.2412 (0.3424)	Error 0.0600 (0.1445)
# Epoch: [1/20]	Iter: [266/596]	Time 0.823 (0.823)	Loss 0.2971 (0.3423)	Error 0.1400 (0.1444)
# Epoch: [1/20]	Iter: [267/596]	Time 0.798 (0.823)	Loss 0.2528 (0.3419)	Error 0.1000 (0.1443)
# Epoch: [1/20]	Iter: [268/596]	Time 0.802 (0.823)	Loss 0.3932 (0.3421)	Error 0.2000 (0.1445)
# Epoch: [1/20]	Iter: [269/596]	Time 0.878 (0.823)	Loss 0.3035 (0.3420)	Error 0.1400 (0.1445)
# Epoch: [1/20]	Iter: [270/596]	Time 0.836 (0.823)	Loss 0.2166 (0.3415)	Error 0.0800 (0.1442)
# Epoch: [1/20]	Iter: [271/596]	Time 0.800 (0.823)	Loss 0.2164 (0.3410)	Error 0.1200 (0.1441)
# Epoch: [1/20]	Iter: [272/596]	Time 0.810 (0.823)	Loss 0.3410 (0.3410)	Error 0.1600 (0.1442)
# Epoch: [1/20]	Iter: [273/596]	Time 0.784 (0.823)	Loss 0.2258 (0.3406)	Error 0.1600 (0.1442)
# Epoch: [1/20]	Iter: [274/596]	Time 0.851 (0.823)	Loss 0.2515 (0.3403)	Error 0.1000 (0.1441)
# Epoch: [1/20]	Iter: [275/596]	Time 0.846 (0.823)	Loss 0.2775 (0.3401)	Error 0.1000 (0.1439)
# Epoch: [1/20]	Iter: [276/596]	Time 0.836 (0.823)	Loss 0.1070 (0.3392)	Error 0.0000 (0.1434)
# Epoch: [1/20]	Iter: [277/596]	Time 0.782 (0.823)	Loss 0.2093 (0.3388)	Error 0.0800 (0.1432)
# Epoch: [1/20]	Iter: [278/596]	Time 0.868 (0.823)	Loss 0.3202 (0.3387)	Error 0.1200 (0.1431)
# Epoch: [1/20]	Iter: [279/596]	Time 0.830 (0.823)	Loss 0.4254 (0.3390)	Error 0.1600 (0.1432)
# Epoch: [1/20]	Iter: [280/596]	Time 0.787 (0.823)	Loss 0.1820 (0.3384)	Error 0.0600 (0.1429)
# Epoch: [1/20]	Iter: [281/596]	Time 0.836 (0.823)	Loss 0.2079 (0.3380)	Error 0.0800 (0.1426)
# Epoch: [1/20]	Iter: [282/596]	Time 0.835 (0.823)	Loss 0.3871 (0.3382)	Error 0.1800 (0.1428)
# Epoch: [1/20]	Iter: [283/596]	Time 0.795 (0.823)	Loss 0.2340 (0.3378)	Error 0.0600 (0.1425)
# Epoch: [1/20]	Iter: [284/596]	Time 0.833 (0.823)	Loss 0.3164 (0.3377)	Error 0.1600 (0.1425)
# Epoch: [1/20]	Iter: [285/596]	Time 0.789 (0.823)	Loss 0.3568 (0.3378)	Error 0.2000 (0.1427)
# Epoch: [1/20]	Iter: [286/596]	Time 0.827 (0.823)	Loss 0.1623 (0.3372)	Error 0.0600 (0.1424)
# Epoch: [1/20]	Iter: [287/596]	Time 0.808 (0.823)	Loss 0.2236 (0.3368)	Error 0.1000 (0.1423)
# Epoch: [1/20]	Iter: [288/596]	Time 0.811 (0.823)	Loss 0.3346 (0.3368)	Error 0.1400 (0.1423)
# Epoch: [1/20]	Iter: [289/596]	Time 0.851 (0.823)	Loss 0.1944 (0.3363)	Error 0.0400 (0.1419)
# Epoch: [1/20]	Iter: [290/596]	Time 0.817 (0.823)	Loss 0.3099 (0.3362)	Error 0.1200 (0.1419)
# Epoch: [1/20]	Iter: [291/596]	Time 0.817 (0.823)	Loss 0.1921 (0.3357)	Error 0.0800 (0.1416)
# Epoch: [1/20]	Iter: [292/596]	Time 0.833 (0.823)	Loss 0.2980 (0.3356)	Error 0.1000 (0.1415)
# Epoch: [1/20]	Iter: [293/596]	Time 0.799 (0.823)	Loss 0.2906 (0.3354)	Error 0.1000 (0.1414)
# Epoch: [1/20]	Iter: [294/596]	Time 0.827 (0.823)	Loss 0.2783 (0.3352)	Error 0.1200 (0.1413)
# Epoch: [1/20]	Iter: [295/596]	Time 0.806 (0.823)	Loss 0.5100 (0.3358)	Error 0.2200 (0.1416)
# Epoch: [1/20]	Iter: [296/596]	Time 0.811 (0.823)	Loss 0.2775 (0.3356)	Error 0.1000 (0.1414)
# Epoch: [1/20]	Iter: [297/596]	Time 0.846 (0.823)	Loss 0.2692 (0.3354)	Error 0.1400 (0.1414)
# Epoch: [1/20]	Iter: [298/596]	Time 0.779 (0.822)	Loss 0.2945 (0.3352)	Error 0.1200 (0.1413)
# Epoch: [1/20]	Iter: [299/596]	Time 0.817 (0.822)	Loss 0.2648 (0.3350)	Error 0.1000 (0.1412)
# Epoch: [1/20]	Iter: [300/596]	Time 0.822 (0.822)	Loss 0.1888 (0.3345)	Error 0.0800 (0.1410)
# Epoch: [1/20]	Iter: [301/596]	Time 0.828 (0.822)	Loss 0.2932 (0.3344)	Error 0.1400 (0.1410)
# Epoch: [1/20]	Iter: [302/596]	Time 0.817 (0.822)	Loss 0.3487 (0.3344)	Error 0.1800 (0.1411)
# Epoch: [1/20]	Iter: [303/596]	Time 0.786 (0.822)	Loss 0.2176 (0.3340)	Error 0.0800 (0.1409)
# Epoch: [1/20]	Iter: [304/596]	Time 0.790 (0.822)	Loss 0.4258 (0.3343)	Error 0.1800 (0.1411)
# Epoch: [1/20]	Iter: [305/596]	Time 0.889 (0.822)	Loss 0.2345 (0.3340)	Error 0.1200 (0.1410)
# Epoch: [1/20]	Iter: [306/596]	Time 0.830 (0.822)	Loss 0.1789 (0.3335)	Error 0.1000 (0.1408)
# Epoch: [1/20]	Iter: [307/596]	Time 0.872 (0.823)	Loss 0.3800 (0.3337)	Error 0.1400 (0.1408)
# Epoch: [1/20]	Iter: [308/596]	Time 0.783 (0.822)	Loss 0.3893 (0.3338)	Error 0.1600 (0.1409)
# Epoch: [1/20]	Iter: [309/596]	Time 0.821 (0.822)	Loss 0.2819 (0.3337)	Error 0.1000 (0.1408)
# Epoch: [1/20]	Iter: [310/596]	Time 0.795 (0.822)	Loss 0.3036 (0.3336)	Error 0.1000 (0.1406)
# Epoch: [1/20]	Iter: [311/596]	Time 0.804 (0.822)	Loss 0.5084 (0.3341)	Error 0.2600 (0.1410)
# Epoch: [1/20]	Iter: [312/596]	Time 0.913 (0.823)	Loss 0.3373 (0.3341)	Error 0.1200 (0.1410)
# Epoch: [1/20]	Iter: [313/596]	Time 0.807 (0.823)	Loss 0.2847 (0.3340)	Error 0.1400 (0.1410)
# Epoch: [1/20]	Iter: [314/596]	Time 0.827 (0.823)	Loss 0.2020 (0.3336)	Error 0.1000 (0.1408)
# Epoch: [1/20]	Iter: [315/596]	Time 0.823 (0.823)	Loss 0.2347 (0.3333)	Error 0.1000 (0.1407)
# Epoch: [1/20]	Iter: [316/596]	Time 0.799 (0.823)	Loss 0.1971 (0.3328)	Error 0.0800 (0.1405)
# Epoch: [1/20]	Iter: [317/596]	Time 0.815 (0.823)	Loss 0.1573 (0.3323)	Error 0.0600 (0.1403)
# Epoch: [1/20]	Iter: [318/596]	Time 1.051 (0.823)	Loss 0.1493 (0.3317)	Error 0.0600 (0.1400)
# Epoch: [1/20]	Iter: [319/596]	Time 0.821 (0.823)	Loss 0.4256 (0.3320)	Error 0.1800 (0.1401)
# Epoch: [1/20]	Iter: [320/596]	Time 0.822 (0.823)	Loss 0.1578 (0.3314)	Error 0.0400 (0.1398)
# Epoch: [1/20]	Iter: [321/596]	Time 0.809 (0.823)	Loss 0.3457 (0.3315)	Error 0.1800 (0.1399)
# Epoch: [1/20]	Iter: [322/596]	Time 0.819 (0.823)	Loss 0.2048 (0.3311)	Error 0.0800 (0.1398)
# Epoch: [1/20]	Iter: [323/596]	Time 0.772 (0.823)	Loss 0.4624 (0.3315)	Error 0.2000 (0.1399)
# Epoch: [1/20]	Iter: [324/596]	Time 0.825 (0.823)	Loss 0.2799 (0.3313)	Error 0.0800 (0.1398)
# Epoch: [1/20]	Iter: [325/596]	Time 0.872 (0.823)	Loss 0.2645 (0.3311)	Error 0.0800 (0.1396)
# Epoch: [1/20]	Iter: [326/596]	Time 0.810 (0.823)	Loss 0.2117 (0.3308)	Error 0.0600 (0.1393)
# Epoch: [1/20]	Iter: [327/596]	Time 0.797 (0.823)	Loss 0.2736 (0.3306)	Error 0.1600 (0.1394)
# Epoch: [1/20]	Iter: [328/596]	Time 0.819 (0.823)	Loss 0.1795 (0.3301)	Error 0.0800 (0.1392)
# Epoch: [1/20]	Iter: [329/596]	Time 0.817 (0.823)	Loss 0.2598 (0.3299)	Error 0.1000 (0.1391)
# Epoch: [1/20]	Iter: [330/596]	Time 0.822 (0.823)	Loss 0.3869 (0.3301)	Error 0.2000 (0.1393)
# Epoch: [1/20]	Iter: [331/596]	Time 0.862 (0.823)	Loss 0.3252 (0.3301)	Error 0.1600 (0.1393)
# Epoch: [1/20]	Iter: [332/596]	Time 0.872 (0.823)	Loss 0.2632 (0.3299)	Error 0.1400 (0.1393)
# Epoch: [1/20]	Iter: [333/596]	Time 0.807 (0.823)	Loss 0.3810 (0.3300)	Error 0.1600 (0.1394)
# Epoch: [1/20]	Iter: [334/596]	Time 0.849 (0.823)	Loss 0.5481 (0.3307)	Error 0.2600 (0.1398)
# Epoch: [1/20]	Iter: [335/596]	Time 0.798 (0.823)	Loss 0.2617 (0.3305)	Error 0.1000 (0.1396)
# Epoch: [1/20]	Iter: [336/596]	Time 0.868 (0.823)	Loss 0.1993 (0.3301)	Error 0.0600 (0.1394)
# Epoch: [1/20]	Iter: [337/596]	Time 0.886 (0.824)	Loss 0.2808 (0.3299)	Error 0.1000 (0.1393)
# Epoch: [1/20]	Iter: [338/596]	Time 0.831 (0.824)	Loss 0.4268 (0.3302)	Error 0.1400 (0.1393)
# Epoch: [1/20]	Iter: [339/596]	Time 0.856 (0.824)	Loss 0.3147 (0.3302)	Error 0.1400 (0.1393)
# Epoch: [1/20]	Iter: [340/596]	Time 0.909 (0.824)	Loss 0.2186 (0.3299)	Error 0.0600 (0.1391)
# Epoch: [1/20]	Iter: [341/596]	Time 0.800 (0.824)	Loss 0.1857 (0.3294)	Error 0.0800 (0.1389)
# Epoch: [1/20]	Iter: [342/596]	Time 0.849 (0.824)	Loss 0.1890 (0.3290)	Error 0.0600 (0.1387)
# Epoch: [1/20]	Iter: [343/596]	Time 0.814 (0.824)	Loss 0.2380 (0.3288)	Error 0.1000 (0.1385)
# Epoch: [1/20]	Iter: [344/596]	Time 0.877 (0.824)	Loss 0.3621 (0.3289)	Error 0.1000 (0.1384)
# Epoch: [1/20]	Iter: [345/596]	Time 0.834 (0.824)	Loss 0.2065 (0.3285)	Error 0.0800 (0.1383)
# Epoch: [1/20]	Iter: [346/596]	Time 0.816 (0.824)	Loss 0.2301 (0.3282)	Error 0.0800 (0.1381)
# Epoch: [1/20]	Iter: [347/596]	Time 0.819 (0.824)	Loss 0.1999 (0.3278)	Error 0.1000 (0.1380)
# Epoch: [1/20]	Iter: [348/596]	Time 0.807 (0.824)	Loss 0.1836 (0.3274)	Error 0.1000 (0.1379)
# Epoch: [1/20]	Iter: [349/596]	Time 0.904 (0.824)	Loss 0.2293 (0.3271)	Error 0.0600 (0.1377)
# Epoch: [1/20]	Iter: [350/596]	Time 0.793 (0.824)	Loss 0.2361 (0.3269)	Error 0.1000 (0.1375)
# Epoch: [1/20]	Iter: [351/596]	Time 0.821 (0.824)	Loss 0.4188 (0.3271)	Error 0.1800 (0.1377)
# Epoch: [1/20]	Iter: [352/596]	Time 0.890 (0.824)	Loss 0.2546 (0.3269)	Error 0.1200 (0.1376)
# Epoch: [1/20]	Iter: [353/596]	Time 0.810 (0.824)	Loss 0.2310 (0.3267)	Error 0.1000 (0.1375)
# Epoch: [1/20]	Iter: [354/596]	Time 0.868 (0.824)	Loss 0.2967 (0.3266)	Error 0.1400 (0.1375)
# Epoch: [1/20]	Iter: [355/596]	Time 0.831 (0.824)	Loss 0.3002 (0.3265)	Error 0.1400 (0.1375)
# Epoch: [1/20]	Iter: [356/596]	Time 0.805 (0.824)	Loss 0.1479 (0.3260)	Error 0.0600 (0.1373)
# Epoch: [1/20]	Iter: [357/596]	Time 0.914 (0.825)	Loss 0.1866 (0.3256)	Error 0.0800 (0.1371)
# Epoch: [1/20]	Iter: [358/596]	Time 0.831 (0.825)	Loss 0.4365 (0.3259)	Error 0.2000 (0.1373)
# Epoch: [1/20]	Iter: [359/596]	Time 0.890 (0.825)	Loss 0.1605 (0.3255)	Error 0.0800 (0.1372)
# Epoch: [1/20]	Iter: [360/596]	Time 0.772 (0.825)	Loss 0.3133 (0.3254)	Error 0.1200 (0.1371)
# Epoch: [1/20]	Iter: [361/596]	Time 0.852 (0.825)	Loss 0.2054 (0.3251)	Error 0.0800 (0.1370)
# Epoch: [1/20]	Iter: [362/596]	Time 0.827 (0.825)	Loss 0.2605 (0.3249)	Error 0.1000 (0.1369)
# Epoch: [1/20]	Iter: [363/596]	Time 0.768 (0.825)	Loss 0.1559 (0.3245)	Error 0.0400 (0.1366)
# Epoch: [1/20]	Iter: [364/596]	Time 0.811 (0.825)	Loss 0.3909 (0.3246)	Error 0.1800 (0.1367)
# Epoch: [1/20]	Iter: [365/596]	Time 0.823 (0.825)	Loss 0.2264 (0.3244)	Error 0.1200 (0.1367)
# Epoch: [1/20]	Iter: [366/596]	Time 0.925 (0.825)	Loss 0.1968 (0.3240)	Error 0.0400 (0.1364)
# Epoch: [1/20]	Iter: [367/596]	Time 0.850 (0.825)	Loss 0.1959 (0.3237)	Error 0.0600 (0.1362)
# Epoch: [1/20]	Iter: [368/596]	Time 0.871 (0.825)	Loss 0.3066 (0.3236)	Error 0.1000 (0.1361)
# Epoch: [1/20]	Iter: [369/596]	Time 0.848 (0.825)	Loss 0.3873 (0.3238)	Error 0.1600 (0.1362)
# Epoch: [1/20]	Iter: [370/596]	Time 0.845 (0.825)	Loss 0.1598 (0.3234)	Error 0.0600 (0.1359)
# Epoch: [1/20]	Iter: [371/596]	Time 0.891 (0.825)	Loss 0.2243 (0.3231)	Error 0.0800 (0.1358)
# Epoch: [1/20]	Iter: [372/596]	Time 0.810 (0.825)	Loss 0.2604 (0.3229)	Error 0.1000 (0.1357)
# Epoch: [1/20]	Iter: [373/596]	Time 0.836 (0.825)	Loss 0.2541 (0.3227)	Error 0.1000 (0.1356)
# Epoch: [1/20]	Iter: [374/596]	Time 0.804 (0.825)	Loss 0.2455 (0.3225)	Error 0.1200 (0.1356)
# Epoch: [1/20]	Iter: [375/596]	Time 0.814 (0.825)	Loss 0.2488 (0.3223)	Error 0.1200 (0.1355)
# Epoch: [1/20]	Iter: [376/596]	Time 0.820 (0.825)	Loss 0.3264 (0.3223)	Error 0.1400 (0.1355)
# Epoch: [1/20]	Iter: [377/596]	Time 0.828 (0.825)	Loss 0.2310 (0.3221)	Error 0.0400 (0.1353)
# Epoch: [1/20]	Iter: [378/596]	Time 0.791 (0.825)	Loss 0.3099 (0.3221)	Error 0.0800 (0.1351)
# Epoch: [1/20]	Iter: [379/596]	Time 0.819 (0.825)	Loss 0.2710 (0.3219)	Error 0.1400 (0.1351)
# Epoch: [1/20]	Iter: [380/596]	Time 0.801 (0.825)	Loss 0.2090 (0.3216)	Error 0.0800 (0.1350)
# Epoch: [1/20]	Iter: [381/596]	Time 0.946 (0.825)	Loss 0.3153 (0.3216)	Error 0.1600 (0.1351)
# Epoch: [1/20]	Iter: [382/596]	Time 0.777 (0.825)	Loss 0.2453 (0.3214)	Error 0.1000 (0.1350)
# Epoch: [1/20]	Iter: [383/596]	Time 0.831 (0.825)	Loss 0.1597 (0.3210)	Error 0.0200 (0.1347)
# Epoch: [1/20]	Iter: [384/596]	Time 0.815 (0.825)	Loss 0.3833 (0.3212)	Error 0.1400 (0.1347)
# Epoch: [1/20]	Iter: [385/596]	Time 0.831 (0.825)	Loss 0.2330 (0.3209)	Error 0.0600 (0.1345)
# Epoch: [1/20]	Iter: [386/596]	Time 0.940 (0.826)	Loss 0.3461 (0.3210)	Error 0.1400 (0.1345)
# Epoch: [1/20]	Iter: [387/596]	Time 0.813 (0.825)	Loss 0.1945 (0.3207)	Error 0.1000 (0.1344)
# Epoch: [1/20]	Iter: [388/596]	Time 0.824 (0.825)	Loss 0.1342 (0.3202)	Error 0.0600 (0.1342)
# Epoch: [1/20]	Iter: [389/596]	Time 0.811 (0.825)	Loss 0.2764 (0.3201)	Error 0.1000 (0.1341)
# Epoch: [1/20]	Iter: [390/596]	Time 0.851 (0.825)	Loss 0.2718 (0.3200)	Error 0.1200 (0.1341)
# Epoch: [1/20]	Iter: [391/596]	Time 0.832 (0.826)	Loss 0.2877 (0.3199)	Error 0.1200 (0.1341)
# Epoch: [1/20]	Iter: [392/596]	Time 0.827 (0.826)	Loss 0.3071 (0.3198)	Error 0.1400 (0.1341)
# Epoch: [1/20]	Iter: [393/596]	Time 0.832 (0.826)	Loss 0.1930 (0.3195)	Error 0.1000 (0.1340)
# Epoch: [1/20]	Iter: [394/596]	Time 0.843 (0.826)	Loss 0.3527 (0.3196)	Error 0.1600 (0.1341)
# Epoch: [1/20]	Iter: [395/596]	Time 0.839 (0.826)	Loss 0.2734 (0.3195)	Error 0.1400 (0.1341)
# Epoch: [1/20]	Iter: [396/596]	Time 0.822 (0.826)	Loss 0.1639 (0.3191)	Error 0.0400 (0.1338)
# Epoch: [1/20]	Iter: [397/596]	Time 0.799 (0.826)	Loss 0.4170 (0.3193)	Error 0.1800 (0.1340)
# Epoch: [1/20]	Iter: [398/596]	Time 0.826 (0.826)	Loss 0.3719 (0.3195)	Error 0.1400 (0.1340)
# Epoch: [1/20]	Iter: [399/596]	Time 0.780 (0.825)	Loss 0.1512 (0.3190)	Error 0.0400 (0.1337)
# Epoch: [1/20]	Iter: [400/596]	Time 0.815 (0.825)	Loss 0.3648 (0.3192)	Error 0.1400 (0.1338)
# Epoch: [1/20]	Iter: [401/596]	Time 0.787 (0.825)	Loss 0.1398 (0.3187)	Error 0.0600 (0.1336)
# Epoch: [1/20]	Iter: [402/596]	Time 0.909 (0.826)	Loss 0.2734 (0.3186)	Error 0.1000 (0.1335)
# Epoch: [1/20]	Iter: [403/596]	Time 0.786 (0.825)	Loss 0.3159 (0.3186)	Error 0.0800 (0.1333)
# Epoch: [1/20]	Iter: [404/596]	Time 0.840 (0.825)	Loss 0.2355 (0.3184)	Error 0.1000 (0.1333)
# Epoch: [1/20]	Iter: [405/596]	Time 0.839 (0.825)	Loss 0.3049 (0.3184)	Error 0.1000 (0.1332)
# Epoch: [1/20]	Iter: [406/596]	Time 0.789 (0.825)	Loss 0.3084 (0.3183)	Error 0.1200 (0.1332)
# Epoch: [1/20]	Iter: [407/596]	Time 0.828 (0.825)	Loss 0.3131 (0.3183)	Error 0.1800 (0.1333)
# Epoch: [1/20]	Iter: [408/596]	Time 0.900 (0.826)	Loss 0.3515 (0.3184)	Error 0.1600 (0.1333)
# Epoch: [1/20]	Iter: [409/596]	Time 0.796 (0.826)	Loss 0.3841 (0.3186)	Error 0.1800 (0.1334)
# Epoch: [1/20]	Iter: [410/596]	Time 0.790 (0.825)	Loss 0.2733 (0.3185)	Error 0.1400 (0.1335)
# Epoch: [1/20]	Iter: [411/596]	Time 0.846 (0.825)	Loss 0.2179 (0.3182)	Error 0.1000 (0.1334)
# Epoch: [1/20]	Iter: [412/596]	Time 0.812 (0.825)	Loss 0.3512 (0.3183)	Error 0.1600 (0.1334)
# Epoch: [1/20]	Iter: [413/596]	Time 0.871 (0.826)	Loss 0.2449 (0.3181)	Error 0.1400 (0.1335)
# Epoch: [1/20]	Iter: [414/596]	Time 0.824 (0.826)	Loss 0.2502 (0.3179)	Error 0.1000 (0.1334)
# Epoch: [1/20]	Iter: [415/596]	Time 0.842 (0.826)	Loss 0.2092 (0.3177)	Error 0.0600 (0.1332)
# Epoch: [1/20]	Iter: [416/596]	Time 0.860 (0.826)	Loss 0.2378 (0.3175)	Error 0.0600 (0.1330)
# Epoch: [1/20]	Iter: [417/596]	Time 0.793 (0.826)	Loss 0.1741 (0.3171)	Error 0.0600 (0.1329)
# Epoch: [1/20]	Iter: [418/596]	Time 0.754 (0.825)	Loss 0.3460 (0.3172)	Error 0.1600 (0.1329)
# Epoch: [1/20]	Iter: [419/596]	Time 0.873 (0.826)	Loss 0.3503 (0.3173)	Error 0.1400 (0.1329)
# Epoch: [1/20]	Iter: [420/596]	Time 0.808 (0.825)	Loss 0.2443 (0.3171)	Error 0.0800 (0.1328)
# Epoch: [1/20]	Iter: [421/596]	Time 0.858 (0.826)	Loss 0.2798 (0.3170)	Error 0.1000 (0.1327)
# Epoch: [1/20]	Iter: [422/596]	Time 0.813 (0.826)	Loss 0.3499 (0.3171)	Error 0.1800 (0.1328)
# Epoch: [1/20]	Iter: [423/596]	Time 0.821 (0.826)	Loss 0.2043 (0.3168)	Error 0.0600 (0.1327)
# Epoch: [1/20]	Iter: [424/596]	Time 0.796 (0.825)	Loss 0.2405 (0.3167)	Error 0.0600 (0.1325)
# Epoch: [1/20]	Iter: [425/596]	Time 0.820 (0.825)	Loss 0.1329 (0.3162)	Error 0.0600 (0.1323)
# Epoch: [1/20]	Iter: [426/596]	Time 0.791 (0.825)	Loss 0.4022 (0.3164)	Error 0.1800 (0.1324)
# Epoch: [1/20]	Iter: [427/596]	Time 0.861 (0.825)	Loss 0.2281 (0.3162)	Error 0.1000 (0.1324)
# Epoch: [1/20]	Iter: [428/596]	Time 0.807 (0.825)	Loss 0.2294 (0.3160)	Error 0.1200 (0.1323)
# Epoch: [1/20]	Iter: [429/596]	Time 0.805 (0.825)	Loss 0.2470 (0.3159)	Error 0.1000 (0.1323)
# Epoch: [1/20]	Iter: [430/596]	Time 0.841 (0.825)	Loss 0.2226 (0.3156)	Error 0.0800 (0.1321)
# Epoch: [1/20]	Iter: [431/596]	Time 0.895 (0.826)	Loss 0.2140 (0.3154)	Error 0.1000 (0.1321)
# Epoch: [1/20]	Iter: [432/596]	Time 0.810 (0.826)	Loss 0.2688 (0.3153)	Error 0.1000 (0.1320)
# Epoch: [1/20]	Iter: [433/596]	Time 0.847 (0.826)	Loss 0.4056 (0.3155)	Error 0.1400 (0.1320)
# Epoch: [1/20]	Iter: [434/596]	Time 0.820 (0.826)	Loss 0.3670 (0.3156)	Error 0.1800 (0.1321)
# Epoch: [1/20]	Iter: [435/596]	Time 0.850 (0.826)	Loss 0.2253 (0.3154)	Error 0.1000 (0.1320)
# Epoch: [1/20]	Iter: [436/596]	Time 0.865 (0.826)	Loss 0.2353 (0.3152)	Error 0.0800 (0.1319)
# Epoch: [1/20]	Iter: [437/596]	Time 0.837 (0.826)	Loss 0.1294 (0.3148)	Error 0.0200 (0.1317)
# Epoch: [1/20]	Iter: [438/596]	Time 0.786 (0.826)	Loss 0.2398 (0.3146)	Error 0.0800 (0.1316)
# Epoch: [1/20]	Iter: [439/596]	Time 0.891 (0.826)	Loss 0.2636 (0.3145)	Error 0.1200 (0.1315)
# Epoch: [1/20]	Iter: [440/596]	Time 0.786 (0.826)	Loss 0.2462 (0.3144)	Error 0.1000 (0.1315)
# Epoch: [1/20]	Iter: [441/596]	Time 0.813 (0.826)	Loss 0.3232 (0.3144)	Error 0.1600 (0.1315)
# Epoch: [1/20]	Iter: [442/596]	Time 0.776 (0.826)	Loss 0.1419 (0.3140)	Error 0.0400 (0.1313)
# Epoch: [1/20]	Iter: [443/596]	Time 0.921 (0.826)	Loss 0.2812 (0.3139)	Error 0.1200 (0.1313)
# Epoch: [1/20]	Iter: [444/596]	Time 0.791 (0.826)	Loss 0.4573 (0.3142)	Error 0.1400 (0.1313)
# Epoch: [1/20]	Iter: [445/596]	Time 0.785 (0.826)	Loss 0.3447 (0.3143)	Error 0.1600 (0.1314)
# Epoch: [1/20]	Iter: [446/596]	Time 0.822 (0.826)	Loss 0.2572 (0.3142)	Error 0.0800 (0.1313)
# Epoch: [1/20]	Iter: [447/596]	Time 0.802 (0.826)	Loss 0.2380 (0.3140)	Error 0.1400 (0.1313)
# Epoch: [1/20]	Iter: [448/596]	Time 0.842 (0.826)	Loss 0.1119 (0.3136)	Error 0.0200 (0.1310)
# Epoch: [1/20]	Iter: [449/596]	Time 0.808 (0.826)	Loss 0.1938 (0.3133)	Error 0.0600 (0.1309)
# Epoch: [1/20]	Iter: [450/596]	Time 0.808 (0.825)	Loss 0.2403 (0.3131)	Error 0.0600 (0.1307)
# Epoch: [1/20]	Iter: [451/596]	Time 0.806 (0.825)	Loss 0.3585 (0.3132)	Error 0.1800 (0.1308)
# Epoch: [1/20]	Iter: [452/596]	Time 0.805 (0.825)	Loss 0.1796 (0.3129)	Error 0.0400 (0.1306)
# Epoch: [1/20]	Iter: [453/596]	Time 0.920 (0.826)	Loss 0.2595 (0.3128)	Error 0.1200 (0.1306)
# Epoch: [1/20]	Iter: [454/596]	Time 0.772 (0.825)	Loss 0.2215 (0.3126)	Error 0.1200 (0.1306)
# Epoch: [1/20]	Iter: [455/596]	Time 0.865 (0.826)	Loss 0.2854 (0.3126)	Error 0.1800 (0.1307)
# Epoch: [1/20]	Iter: [456/596]	Time 0.810 (0.826)	Loss 0.2338 (0.3124)	Error 0.1200 (0.1307)
# Epoch: [1/20]	Iter: [457/596]	Time 0.882 (0.826)	Loss 0.3619 (0.3125)	Error 0.1600 (0.1307)
# Epoch: [1/20]	Iter: [458/596]	Time 0.773 (0.826)	Loss 0.1581 (0.3122)	Error 0.0600 (0.1306)
# Epoch: [1/20]	Iter: [459/596]	Time 0.822 (0.826)	Loss 0.1531 (0.3118)	Error 0.0400 (0.1304)
# Epoch: [1/20]	Iter: [460/596]	Time 0.794 (0.825)	Loss 0.2924 (0.3118)	Error 0.1600 (0.1304)
# Epoch: [1/20]	Iter: [461/596]	Time 0.762 (0.825)	Loss 0.1818 (0.3115)	Error 0.1000 (0.1304)
# Epoch: [1/20]	Iter: [462/596]	Time 0.808 (0.825)	Loss 0.1824 (0.3112)	Error 0.0800 (0.1303)
# Epoch: [1/20]	Iter: [463/596]	Time 0.803 (0.825)	Loss 0.4564 (0.3115)	Error 0.1800 (0.1304)
# Epoch: [1/20]	Iter: [464/596]	Time 0.868 (0.825)	Loss 0.2758 (0.3114)	Error 0.1000 (0.1303)
# Epoch: [1/20]	Iter: [465/596]	Time 0.798 (0.825)	Loss 0.2150 (0.3112)	Error 0.0800 (0.1302)
# Epoch: [1/20]	Iter: [466/596]	Time 0.874 (0.825)	Loss 0.3026 (0.3112)	Error 0.1400 (0.1302)
# Epoch: [1/20]	Iter: [467/596]	Time 0.790 (0.825)	Loss 0.2742 (0.3111)	Error 0.1200 (0.1302)
# Epoch: [1/20]	Iter: [468/596]	Time 0.811 (0.825)	Loss 0.1498 (0.3108)	Error 0.0600 (0.1300)
# Epoch: [1/20]	Iter: [469/596]	Time 0.864 (0.825)	Loss 0.3115 (0.3108)	Error 0.1200 (0.1300)
# Epoch: [1/20]	Iter: [470/596]	Time 0.810 (0.825)	Loss 0.4884 (0.3112)	Error 0.1800 (0.1301)
# Epoch: [1/20]	Iter: [471/596]	Time 0.797 (0.825)	Loss 0.2414 (0.3110)	Error 0.1000 (0.1301)
# Epoch: [1/20]	Iter: [472/596]	Time 0.805 (0.825)	Loss 0.2255 (0.3108)	Error 0.0800 (0.1300)
# Epoch: [1/20]	Iter: [473/596]	Time 0.961 (0.826)	Loss 0.4588 (0.3112)	Error 0.1800 (0.1301)
# Epoch: [1/20]	Iter: [474/596]	Time 0.793 (0.825)	Loss 0.3827 (0.3113)	Error 0.2000 (0.1302)
# Epoch: [1/20]	Iter: [475/596]	Time 0.844 (0.825)	Loss 0.1224 (0.3109)	Error 0.0400 (0.1300)
# Epoch: [1/20]	Iter: [476/596]	Time 0.771 (0.825)	Loss 0.1865 (0.3107)	Error 0.0800 (0.1299)
# Epoch: [1/20]	Iter: [477/596]	Time 0.801 (0.825)	Loss 0.2843 (0.3106)	Error 0.1000 (0.1299)
# Epoch: [1/20]	Iter: [478/596]	Time 0.822 (0.825)	Loss 0.1973 (0.3104)	Error 0.0400 (0.1297)
# Epoch: [1/20]	Iter: [479/596]	Time 0.813 (0.825)	Loss 0.2907 (0.3103)	Error 0.1400 (0.1297)
# Epoch: [1/20]	Iter: [480/596]	Time 0.808 (0.825)	Loss 0.3827 (0.3105)	Error 0.1600 (0.1298)
# Epoch: [1/20]	Iter: [481/596]	Time 0.777 (0.825)	Loss 0.4497 (0.3108)	Error 0.2000 (0.1299)
# Epoch: [1/20]	Iter: [482/596]	Time 0.906 (0.825)	Loss 0.1861 (0.3105)	Error 0.0800 (0.1298)
# Epoch: [1/20]	Iter: [483/596]	Time 0.838 (0.825)	Loss 0.2715 (0.3104)	Error 0.1400 (0.1298)
# Epoch: [1/20]	Iter: [484/596]	Time 0.798 (0.825)	Loss 0.2199 (0.3102)	Error 0.0800 (0.1297)
# Epoch: [1/20]	Iter: [485/596]	Time 0.821 (0.825)	Loss 0.2383 (0.3101)	Error 0.0800 (0.1296)
# Epoch: [1/20]	Iter: [486/596]	Time 0.848 (0.825)	Loss 0.3614 (0.3102)	Error 0.1400 (0.1296)
# Epoch: [1/20]	Iter: [487/596]	Time 0.787 (0.825)	Loss 0.2332 (0.3100)	Error 0.1200 (0.1296)
# Epoch: [1/20]	Iter: [488/596]	Time 0.828 (0.825)	Loss 0.2173 (0.3098)	Error 0.0800 (0.1295)
# Epoch: [1/20]	Iter: [489/596]	Time 0.802 (0.825)	Loss 0.2107 (0.3096)	Error 0.0800 (0.1294)
# Epoch: [1/20]	Iter: [490/596]	Time 0.831 (0.825)	Loss 0.1687 (0.3094)	Error 0.0800 (0.1293)
# Epoch: [1/20]	Iter: [491/596]	Time 0.842 (0.825)	Loss 0.1828 (0.3091)	Error 0.0600 (0.1292)
# Epoch: [1/20]	Iter: [492/596]	Time 0.859 (0.825)	Loss 0.2573 (0.3090)	Error 0.1000 (0.1291)
# Epoch: [1/20]	Iter: [493/596]	Time 0.842 (0.825)	Loss 0.2946 (0.3090)	Error 0.1400 (0.1291)
# Epoch: [1/20]	Iter: [494/596]	Time 0.834 (0.825)	Loss 0.3212 (0.3090)	Error 0.1400 (0.1291)
# Epoch: [1/20]	Iter: [495/596]	Time 0.807 (0.825)	Loss 0.2657 (0.3089)	Error 0.0800 (0.1291)
# Epoch: [1/20]	Iter: [496/596]	Time 0.812 (0.825)	Loss 0.1236 (0.3085)	Error 0.0600 (0.1289)
# Epoch: [1/20]	Iter: [497/596]	Time 0.810 (0.825)	Loss 0.3439 (0.3086)	Error 0.1600 (0.1290)
# Epoch: [1/20]	Iter: [498/596]	Time 0.793 (0.825)	Loss 0.2178 (0.3084)	Error 0.0600 (0.1288)
# Epoch: [1/20]	Iter: [499/596]	Time 0.770 (0.825)	Loss 0.2945 (0.3084)	Error 0.1000 (0.1288)
# Epoch: [1/20]	Iter: [500/596]	Time 0.822 (0.825)	Loss 0.3563 (0.3085)	Error 0.1600 (0.1288)
# Epoch: [1/20]	Iter: [501/596]	Time 0.880 (0.825)	Loss 0.3362 (0.3085)	Error 0.1400 (0.1289)
# Epoch: [1/20]	Iter: [502/596]	Time 0.821 (0.825)	Loss 0.3088 (0.3085)	Error 0.1200 (0.1288)
# Epoch: [1/20]	Iter: [503/596]	Time 0.845 (0.825)	Loss 0.1653 (0.3083)	Error 0.0600 (0.1287)
# Epoch: [1/20]	Iter: [504/596]	Time 0.831 (0.825)	Loss 0.2188 (0.3081)	Error 0.1200 (0.1287)
# Epoch: [1/20]	Iter: [505/596]	Time 0.821 (0.825)	Loss 0.3183 (0.3081)	Error 0.1000 (0.1286)
# Epoch: [1/20]	Iter: [506/596]	Time 0.815 (0.825)	Loss 0.3013 (0.3081)	Error 0.1600 (0.1287)
# Epoch: [1/20]	Iter: [507/596]	Time 0.842 (0.825)	Loss 0.3067 (0.3081)	Error 0.1200 (0.1287)
# Epoch: [1/20]	Iter: [508/596]	Time 0.825 (0.825)	Loss 0.2499 (0.3080)	Error 0.1000 (0.1286)
# Epoch: [1/20]	Iter: [509/596]	Time 0.808 (0.825)	Loss 0.2160 (0.3078)	Error 0.0800 (0.1285)
# Epoch: [1/20]	Iter: [510/596]	Time 0.863 (0.825)	Loss 0.2842 (0.3077)	Error 0.1400 (0.1285)
# Epoch: [1/20]	Iter: [511/596]	Time 0.823 (0.825)	Loss 0.2166 (0.3076)	Error 0.1000 (0.1285)
# Epoch: [1/20]	Iter: [512/596]	Time 0.829 (0.825)	Loss 0.1639 (0.3073)	Error 0.1000 (0.1284)
# Epoch: [1/20]	Iter: [513/596]	Time 0.833 (0.825)	Loss 0.2168 (0.3071)	Error 0.1000 (0.1284)
# Epoch: [1/20]	Iter: [514/596]	Time 0.811 (0.825)	Loss 0.3060 (0.3071)	Error 0.1600 (0.1284)
# Epoch: [1/20]	Iter: [515/596]	Time 0.800 (0.825)	Loss 0.2388 (0.3070)	Error 0.1200 (0.1284)
# Epoch: [1/20]	Iter: [516/596]	Time 0.861 (0.825)	Loss 0.3985 (0.3071)	Error 0.1400 (0.1284)
# Epoch: [1/20]	Iter: [517/596]	Time 0.871 (0.825)	Loss 0.4525 (0.3074)	Error 0.1600 (0.1285)
# Epoch: [1/20]	Iter: [518/596]	Time 0.770 (0.825)	Loss 0.2616 (0.3073)	Error 0.1000 (0.1285)
# Epoch: [1/20]	Iter: [519/596]	Time 0.800 (0.825)	Loss 0.1946 (0.3071)	Error 0.1200 (0.1284)
# Epoch: [1/20]	Iter: [520/596]	Time 0.817 (0.825)	Loss 0.2604 (0.3070)	Error 0.1400 (0.1285)
# Epoch: [1/20]	Iter: [521/596]	Time 0.844 (0.825)	Loss 0.1655 (0.3068)	Error 0.1000 (0.1284)
# Epoch: [1/20]	Iter: [522/596]	Time 0.831 (0.825)	Loss 0.3244 (0.3068)	Error 0.1200 (0.1284)
# Epoch: [1/20]	Iter: [523/596]	Time 0.815 (0.825)	Loss 0.2858 (0.3068)	Error 0.1200 (0.1284)
# Epoch: [1/20]	Iter: [524/596]	Time 0.842 (0.825)	Loss 0.2618 (0.3067)	Error 0.1000 (0.1283)
# Epoch: [1/20]	Iter: [525/596]	Time 0.842 (0.825)	Loss 0.2529 (0.3066)	Error 0.1000 (0.1283)
# Epoch: [1/20]	Iter: [526/596]	Time 0.885 (0.825)	Loss 0.2722 (0.3065)	Error 0.0800 (0.1282)
# Epoch: [1/20]	Iter: [527/596]	Time 0.813 (0.825)	Loss 0.2680 (0.3064)	Error 0.1800 (0.1283)
# Epoch: [1/20]	Iter: [528/596]	Time 0.823 (0.825)	Loss 0.2626 (0.3063)	Error 0.1400 (0.1283)
# Epoch: [1/20]	Iter: [529/596]	Time 0.861 (0.825)	Loss 0.3518 (0.3064)	Error 0.1200 (0.1283)
# Epoch: [1/20]	Iter: [530/596]	Time 0.824 (0.825)	Loss 0.2105 (0.3062)	Error 0.0800 (0.1282)
# Epoch: [1/20]	Iter: [531/596]	Time 0.865 (0.826)	Loss 0.1500 (0.3060)	Error 0.0600 (0.1281)
# Epoch: [1/20]	Iter: [532/596]	Time 1.050 (0.826)	Loss 0.1925 (0.3057)	Error 0.0600 (0.1279)
# Epoch: [1/20]	Iter: [533/596]	Time 0.806 (0.826)	Loss 0.2606 (0.3057)	Error 0.0800 (0.1278)
# Epoch: [1/20]	Iter: [534/596]	Time 0.767 (0.826)	Loss 0.4122 (0.3059)	Error 0.1400 (0.1279)
# Epoch: [1/20]	Iter: [535/596]	Time 0.801 (0.826)	Loss 0.2897 (0.3058)	Error 0.1400 (0.1279)
# Epoch: [1/20]	Iter: [536/596]	Time 0.798 (0.826)	Loss 0.1792 (0.3056)	Error 0.0400 (0.1277)
# Epoch: [1/20]	Iter: [537/596]	Time 0.852 (0.826)	Loss 0.1852 (0.3054)	Error 0.0800 (0.1276)
# Epoch: [1/20]	Iter: [538/596]	Time 0.835 (0.826)	Loss 0.3134 (0.3054)	Error 0.1200 (0.1276)
# Epoch: [1/20]	Iter: [539/596]	Time 0.850 (0.826)	Loss 0.2663 (0.3053)	Error 0.1000 (0.1276)
# Epoch: [1/20]	Iter: [540/596]	Time 0.823 (0.826)	Loss 0.4185 (0.3055)	Error 0.2000 (0.1277)
# Epoch: [1/20]	Iter: [541/596]	Time 0.833 (0.826)	Loss 0.2609 (0.3054)	Error 0.1200 (0.1277)
# Epoch: [1/20]	Iter: [542/596]	Time 0.786 (0.826)	Loss 0.4190 (0.3056)	Error 0.1400 (0.1277)
# Epoch: [1/20]	Iter: [543/596]	Time 0.808 (0.826)	Loss 0.2393 (0.3055)	Error 0.0800 (0.1276)
# Epoch: [1/20]	Iter: [544/596]	Time 0.805 (0.826)	Loss 0.2095 (0.3053)	Error 0.1000 (0.1276)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6124f78a524e> in <module>()
#       9       wd=0.0001,
#      10       momentum=0.9,
# ---> 11       seed=None)
#
# /ext2/feng/feng/workspace/residential_building_challenge/solver.py in train(model, train_set, test_set, save, n_epochs, valid_size, batch_size, lr, wd, momentum, seed)
#     170             optimizer=optimizer,
#     171             epoch=epoch,
# --> 172             n_epochs=n_epochs,
#     173         )
#     174         _, valid_loss, valid_error = test_epoch(
#
# /ext2/feng/feng/workspace/residential_building_challenge/solver.py in train_epoch(model, loader, optimizer, epoch, n_epochs, print_freq)
#      29
#      30         # compute output
# ---> 31         output = model(input_var)
#      32         loss = torch.nn.functional.cross_entropy(output, target_var)
#      33
#
# ~/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# /ext2/feng/feng/workspace/residential_building_challenge/densenet_efficient.py in forward(self, x)
#     200
#     201     def forward(self, x):
# --> 202         features = self.features(x)
#     203         out = F.relu(features, inplace=True)
#     204         out = F.avg_pool2d(out, kernel_size=self.avgpool_size).view(
#
# ~/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# /ext2/feng/feng/workspace/residential_building_challenge/densenet_efficient.py in forward(self, x)
#     135         outputs = [x]
#     136         for module in self.children():
# --> 137             outputs.append(module.forward(outputs))
#     138         return torch.cat(outputs, dim=1)
#     139
#
# /ext2/feng/feng/workspace/residential_building_challenge/densenet_efficient.py in forward(self, x)
#      92         else:
#      93             prev_features = x
# ---> 94         new_features = super(_DenseLayer, self).forward(prev_features)
#      95         if self.drop_rate > 0:
#      96             new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
#
# ~/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# /ext2/feng/feng/workspace/residential_building_challenge/densenet_efficient.py in forward(self, inputs)
#      55         # These intermediate feature maps have to be re-populated before the backward pass
#      56         fn = _EfficientDensenetBottleneckFn(self.shared_allocation_1, self.shared_allocation_2,
# ---> 57                                             self.norm_running_mean, self.norm_running_var,
#      58                                             training=self.training, momentum=0.1, eps=1e-5)
#      59         relu_output = fn(self.norm_weight, self.norm_bias, *inputs)
#
# ~/anaconda3/envs/rbc_env/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     351
#     352     def __getattr__(self, name):
# --> 353         if '_parameters' in self.__dict__:
#     354             _parameters = self.__dict__['_parameters']
#     355             if name in _parameters:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualization
# Visualize training and validation accuracy throughout training history.
# Visualize loss function.

# %%
train_loss = []
train_acc = []
valid_loss = []
valid_acc = []

with open(os.path.join('/home/feng/ext2/feng/workspace/residential_building_challenge/20to2_fmow_output', 'results.csv'), 'r') as f:
        for line in f:
            numbers = line.split(',')
            if(numbers[0]=='epoch'):
                continue
            try:
                train_loss.append(float(numbers[1]))
                train_acc.append(1-float(numbers[2]))
                valid_loss.append(float(numbers[3]))
                valid_acc.append(1-float(numbers[4]))
            except ValueError:
                continue


# Visualize loss history and training/validation accuracy history
plt.subplot(2, 1, 1)
plt.plot(train_loss, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(train_acc, '-o')
plt.plot(valid_acc, '-o')
plt.legend(['train', 'val'], loc='lower right')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# ## Test Model
# Make predictions based on test dataset. Visually assess the quality of prediction and compute accuracy based on groundtruth.

# %%
# Check accuracy of model on Test set
test_loader = torch.utils.data.DataLoader(test_set, batch_size=16, shuffle=False,
                                              pin_memory=(torch.cuda.is_available()), num_workers=0)
test_epoch(model, test_loader)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-f7c351516230> in <module>()
#       2 test_loader = torch.utils.data.DataLoader(test_set, batch_size=16, shuffle=False,
#       3                                               pin_memory=(torch.cuda.is_available()), num_workers=0)
# ----> 4 test_epoch(model, test_loader)
#
# /ext2/feng/feng/workspace/residential_building_challenge/solver.py in test_epoch(model, loader, print_freq, is_test)
#      95         error.update(torch.ne(pred.squeeze(), target.cpu()).float().sum() / batch_size, batch_size)
#      96         losses.update(loss.data[0], batch_size)
# ---> 97         confusion.add(pred.squeeze(), target.cpu())
#      98
#      99         # measure elapsed time
#
# /ext2/feng/feng/workspace/residential_building_challenge/meter.py in add(self, predicted, target)
#      75         else:
#      76             assert (predicted.max() < self.k) and (predicted.min() >= 0), \
# ---> 77                 'predicted values are not between 1 and k'
#      78
#      79         onehot_target = np.ndim(target) != 1
#
# AssertionError: predicted values are not between 1 and k

# %% [markdown]
# ### Visualize Successful and Failed Examples

# %%
x = np.array([[1,2],[2,3],[3,4]])
mask = [False,False,True]
print(x)

# %%
X_success = np.array([]).reshape((0, 1, 200, 200))
y_success = np.array([]).reshape((0,))
X_failure = np.array([]).reshape((0, 1, 200, 200))
y_failure = np.array([]).reshape((0,))

model.eval() 
for X, y in loader_test:
    X_var = Variable(X.type(dtype), volatile=True)
    scores = model(X_var)
    _, preds = scores.data.cpu().max(1)
    idx_success = (preds == y).numpy() == 1
    idx_failure = (preds != y).numpy() == 1
    X = X.numpy()
    y = y.numpy()
    X_success = np.append(X_success, X[idx_success.tolist(), :, :, :], axis=0)
    y_success = np.append(y_success, y[idx_success.tolist(), ], axis=0)
    X_failure = np.append(X_failure, X[idx_failure.tolist(), :, :, :], axis=0)
    y_failure = np.append(y_failure, preds[idx_failure.tolist(), ], axis=0)
    
y_success = y_success.astype(np.int32)
y_failure = y_failure.astype(np.int32)

# %%
# Sample a batch of successfully classified images
for i in range(12):
    plt.subplot(3, 4, i+1)
    img = np.moveaxis(X_success[i, :, :, :], 0, -1)
    plt.imshow(img[:,:,0])
    plt.axis('off')
    plt.title(rbc_class_names[y_success[i]])
    plt.show()

# %%
# Sample a batch of incorrectly classified images
plt.title('Failure Examples')
for i in range(8):
    plt.subplot(2, 4, i+1)
    img = np.moveaxis(X_failure[i, :, :, :], 0, -1)
    plt.imshow(img[:,:,0])
    plt.axis('off')
    plt.title(rbc_class_names[y_failure[i]])
    plt.show()
